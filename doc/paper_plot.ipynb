# %%
import numpy as np
import math, cmath
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x = np.linspace (-np.pi/2 , np.pi/2 , 100)
plt.plot(x, np.sin(x))

# %%
tilde_M = 9
m = np.linspace(0, tilde_M-1, tilde_M)    
y = 2/tilde_M*(m-np.floor((tilde_M-1)/2))
plt.plot(m, np.arcsin(y))
plt.scatter(m,np.arcsin(y))

# %%
A = np.mat([[1,2,3], [4,5,6], [7,8,9]])
X = np.mat([[0,0,0],
            [0,0,1], 
            [0,0,0]])
A*X*A.H
# Out:
# matrix([[ 6, 12, 18],
#         [15, 30, 45],
#         [24, 48, 72]])

# %% [markdown]
# ## Gamma 函数模拟
# scipy 函数库中的Gamma函数
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.gamma.html
# numpy 函数库中：
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.gamma.html
# 对比numpy，scipy中的gamma函数有ppf、pdf等方便的子类，而numpy只能生成随机数。

# %%
from scipy.stats import gamma
a=0.01
b=0.01
scale = 1/b

x = np.linspace(0,20, 100)    
y = gamma.pdf(x, a=a, loc=0, scale=scale)
plt.plot(x, y)

# %%
import numpy as np
import math, cmath
import matplotlib as mpl
import matplotlib.pyplot as plt

a = np.random.randn(10000,2).view(np.complex128)*np.power(2,-1/2)

# %%
import numpy as np
import math, cmath
import matplotlib as mpl
import matplotlib.pyplot as plt

N = 16
x = np.array(range(N))
e_seq = np.exp(-1j*2*np.pi*x*-0.125)
print(e_seq)
plt.plot(x, np.fft.ifft(e_seq))
print(np.fft.fft(e_seq))
# Out:
# [ 1.00000000e+00+0.00000000e+00j  7.07106781e-01+7.07106781e-01j
#   6.12323400e-17+1.00000000e+00j -7.07106781e-01+7.07106781e-01j
#  -1.00000000e+00+1.22464680e-16j -7.07106781e-01-7.07106781e-01j
#  -1.83697020e-16-1.00000000e+00j  7.07106781e-01-7.07106781e-01j
#   1.00000000e+00-2.44929360e-16j  7.07106781e-01+7.07106781e-01j
#   3.06161700e-16+1.00000000e+00j -7.07106781e-01+7.07106781e-01j
#  -1.00000000e+00+3.67394040e-16j -7.07106781e-01-7.07106781e-01j
#  -4.28626380e-16-1.00000000e+00j  7.07106781e-01-7.07106781e-01j]
# [ 1.99159850e-16-6.43249060e-16j -1.60973460e-15-6.96959964e-18j
#   1.60000000e+01-4.37904078e-15j  1.46467697e-15-6.70544368e-17j
#   2.44929360e-16-1.99159850e-16j  1.12414598e-15-1.81378481e-15j
#   2.66453526e-15-6.43249060e-16j  9.81324688e-16+2.15858590e-15j
#  -6.89018570e-16+1.13310778e-15j  4.27111034e-16+4.96828319e-16j
#   0.00000000e+00+9.50029740e-16j -2.82053405e-16+5.56913156e-16j
#   2.44929360e-16+6.89018570e-16j -9.21239851e-16+2.30364353e-15j
#  -2.66453526e-15+1.13310778e-15j -1.18423081e-15-1.66872718e-15j]
# /Users/guoxufeng/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
import numpy as np
import math, cmath
import matplotlib as mpl
import matplotlib.pyplot as plt

N = int(2**15)
x = np.array(range(N))
AWGN = np.random.randn(N)
plt.subplot(2,1,1)
plt.plot(x,AWGN)
plt.subplot(2,1,2)
plt.plot(x, np.fft.fft(AWGN)/np.power(N,1/2))

import plotly as py
import plotly.graph_objs as go
import  numpy as np
import plotly.figure_factory as ff
pyolt=py.offline.plot

#添加直方图数据
# s1=np.random.RandomState(12)
#柯西分布
# x1=s1.standard_cauchy(200)-4
# #泊松分布
# x2=s1.uniform(1,10,200)
# #Gamma分布
# x3=s1.standard_gamma(3,200)+4
# #指数分布
# x4=s1.exponential(3,200)+8

#数据组
fft_real = np.real(np.fft.fft(AWGN)/np.power(N,1/2))
fft_imag = np.imag(np.fft.fft(AWGN)/np.power(N,1/2))
# fft_real_div_N = np.imag(np.fft.fft(AWGN)/N)
hist_data=[AWGN,fft_real,fft_imag]

group_labels=['F','W']

# fig=ff.create_distplot(hist_data,group_labels,bin_size=0.05)
# pyolt(fig,filename='F_original.html')
# hist_data=[(F-F_avg)/F_std,W_n1_log_n1]

# group_labels=['F','W']

# fig=ff.create_distplot(hist_data,group_labels,bin_size=0.05)
# pyolt(fig,filename='F_after.html')
# hist_data=[(F-F_avg)/F_std,(W-W_avg)/W_std]

group_labels=['row','fft_real','fft_imag']

fig=ff.create_distplot(hist_data,group_labels,bin_size=0.05)
pyolt(fig,filename='AWGN_fft.html')
# Out:
# /Users/guoxufeng/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning:
#
# Casting complex values to real discards the imaginary part
# 'AWGN_fft.html'

# %%
print(np.std(AWGN),
np.std(fft_real),
np.std(fft_imag),np.power(2,-1/2))
# Out:
# 0.9973093397527497 0.709351822441688 0.7010279401764141 0.7071067811865476
